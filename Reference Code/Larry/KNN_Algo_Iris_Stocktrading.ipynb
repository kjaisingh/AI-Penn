# %% [markdown]
#    <h1><center>Machine Learning, Lecture 1<br><br><font color=' #7cb342 '> What is Machine Learning?</font><br><font color=' blue '>KNN Machine Learning Model</font><br><font color='gold'>Building Algo Trading Strategy Using KNN Model</font><center></h1>
#   <h3><center>Wave Learning</font><center></h3>
#       <h4><center><i>Larry Huang, Jeffrey Huang</i></center></h4>

# %% [markdown]
# <h1><center><font color='red'>  ***PLEASE MAKE A COPY OF THIS DOCUMENT SO YOU CAN EDIT IT!*** <center></h1>
#
# ---

# %% [markdown]
# #<font color=' #7cb342 '>What is Machine Learning?</font>

# %% [markdown]
# We will learn a lot of **new terminologies** in this club.  Each new terminology will bring a new concept and **open a new window for us**.  So please be **patient**.  All of that will feel natural to you soon.

# %% [markdown]
# ##<font color=' #7cb342 '>What is "**Machine Learning**"?</font>
#
# Everyone know what is a "**Machine**".  Yes, it is a computer program.
# <br>
#
# "**Learning**" is the means of building models of data.
# <br><br>
#
# ##<font color=' #7cb342 '>Then, what is a "model"?</font>
#
# A **model** is a representation of structure and relationship in data.  It helps us understand data.
# <br><br>
#
# ## <font color=' #7cb342 '>The "Learning" process</font>
# We (human or computer) give these models tunable parameters  so that **machine** could apply these model/parameters to observed data and tell us which model **fits** (explains) data better.  This process can be considered as **"Learning" from the data.**
# <br><br>
#
#   ## <font color=' #7cb342 '>Predictive Modelling</font>
# Such "**learned**" model could then be applied to new (previously unseen) data to help understanding and make prediction.
# <br><br>
#
#
#   ## <font color=' #7cb342 '>Why Machine Learning?</font>
# Machine Learning is most effective in the areas that traditional modeling methods don't work.  For example, when observed data doesn't have a traditional pattern, or when observed data is so complex that traditional methods would take prohibited time to calculate (This could be the same case for Machine Learning too).
# <br>
# Noticed that complex datasets and big data are everywhere in our lives.
# <br><br>
# Machine Learning is now mature enough to be used as effective powerful tools.
# <br><br>
# Understanding the problem setting in machine learning is essential to using these tools effectively.
# <br><br>
#
# ## Machine Learning has been adopted like crazy recently, similar to the "Internet Bubble" in year 2000.
# You will **live in the world of Machine Learning in the near future, just like you are living in the world of Internet NOW**.  So **don't be afraid of the buzz words.  Let's learn it together.**

# %% [markdown]
# ## <font color=' #7cb342 '>Supervised Learning vs Unsupervised Learning</font>

# %% [markdown]
# Supervised learning is the most common.  Its observed data is associated with a label (either observed or specified by experts).  Once learned, the model will be used to predict label on new unseen data.
# <br><br>
#
#
# Unsupervised learning involves modeling the features of a dataset without reference to any label.  Hence it is often described as "letting the dataset speak for itself." These models include structurable tasks such as clustering (identifying distinct groups of data).

# %% [markdown]
# ## <font color=' #7cb342 '>Supervised Learning: Classification vs. Regression</font>

# %% [markdown]
# When you are predicting a type, a category or a label, you are performing **Classification** task.
# <br>
# When you are predicting a numerical value or a continuous quantity, you are typically performing **Regression** task.
# <br><br>
# For example, predicting stock price is a **Regression** task, while predicting the winner of a presidential election is **Classification** task.

# %% [markdown]
# #<font color=' blue '> Iris Dataset</font>

# %% [markdown]
# ## <font color=' #7cb342 '>Iris Flower</font>

# %% [markdown]
# The Iris flower data set, or Fisher's Iris data set, is a multivariate data set introduced by the British biologist Ronald Fisher in his 1936 paper.  The data is collected to quantify the morphologic variation of Iris flowers of three related species, Iris Versicolor, Iris Virginica, and Iris Setosa.
# <br><br>
# Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
# <br><br>
# Two of the three species were collected in the Gaspé Peninsula (Quebec, Canada) "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".
#
# ![alt text](http://suruchifialoke.com/img/ML/iris.png)

# %% [markdown]
# ##<font color=' #7cb342 '>Predicting Iris Flower Type</font>

# %% [markdown]
# Predicting a label/type, hence this is Supervised **Classification** task.
# <br><br>
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTrUKiJ79RI8lFQP7kqOnMZXxeZTAS4zin9Fh1yWx4SNRgvOaJ0TA)

# %% [markdown]
# # <font color=' blue '>Machine Learning Dataset Repository</font>

# %% [markdown]
# [Iris dataset](https://archive.ics.uci.edu/ml/datasets/Iris) is the most popular dataset in [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php) with 2.2 million hits since 2007.  You could find many other datasets in the same repository.
# <br><br>![alt text](https://archive.ics.uci.edu/ml/assets/logo.gif)
# <br><br>
# ##This repository would be used as one of the dataset repositories for our **capstone** **projects**.

# %% [markdown]
# #<font color='blue '>Data Acquisition</font>

# %% [markdown]
# ##Pandas Basics

# %% [markdown]
# It's an indispensable library for Python Data Science, includes powerful yet convenient data manipulation, data acquisition and visualization features.

# %%
import pandas as pd

# %% [markdown]
# #### Data Acquisition

# %% [markdown]
# Very easy to fetch [data](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data) from Internet, and save them into Pandas DataFrame type (the most data type in Pandas).

# %%
df=pd.read_csv(r"https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
              header=None)

type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ####The original data from UCI does not have data header.  We need to set it ourselves.  The column names come from [UCI data description](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.names) (Section 7. Attribute Information).

# %%
col= ['sepal length in cm', 
      'sepal width in cm', 
      'petal length in cm', 
      'petal width in cm',
      'class']
df.columns = col

# %% [markdown]
# ####Get a feel of the data.

# %%
df.head()
# Out:
#    sepal length in cm  sepal width in cm  ...  petal width in cm        class
# 0                 5.1                3.5  ...                0.2  Iris-setosa
# 1                 4.9                3.0  ...                0.2  Iris-setosa
# 2                 4.7                3.2  ...                0.2  Iris-setosa
# 3                 4.6                3.1  ...                0.2  Iris-setosa
# 4                 5.0                3.6  ...                0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
# First two rows only
df.head(2)
# Out:
#    sepal length in cm  sepal width in cm  ...  petal width in cm        class
# 0                 5.1                3.5  ...                0.2  Iris-setosa
# 1                 4.9                3.0  ...                0.2  Iris-setosa
#
# [2 rows x 5 columns]

# %%
df.tail()
# Out:
#      sepal length in cm  sepal width in cm  ...  petal width in cm           class
# 145                 6.7                3.0  ...                2.3  Iris-virginica
# 146                 6.3                2.5  ...                1.9  Iris-virginica
# 147                 6.5                3.0  ...                2.0  Iris-virginica
# 148                 6.2                3.4  ...                2.3  Iris-virginica
# 149                 5.9                3.0  ...                1.8  Iris-virginica
#
# [5 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal length in cm', 'sepal width in cm', 'petal length in cm',
#        'petal width in cm', 'class'],
#       dtype='object')

# %%
df
# Out:
#      sepal length in cm  sepal width in cm  ...  petal width in cm           class
# 0                   5.1                3.5  ...                0.2     Iris-setosa
# 1                   4.9                3.0  ...                0.2     Iris-setosa
# 2                   4.7                3.2  ...                0.2     Iris-setosa
# 3                   4.6                3.1  ...                0.2     Iris-setosa
# 4                   5.0                3.6  ...                0.2     Iris-setosa
# ..                  ...                ...  ...                ...             ...
# 145                 6.7                3.0  ...                2.3  Iris-virginica
# 146                 6.3                2.5  ...                1.9  Iris-virginica
# 147                 6.5                3.0  ...                2.0  Iris-virginica
# 148                 6.2                3.4  ...                2.3  Iris-virginica
# ...

# %% [markdown]
# ####Summary information

# %%
# Should be a 150x5 matrix
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal length in cm  150 non-null    float64
#  1   sepal width in cm   150 non-null    float64
#  2   petal length in cm  150 non-null    float64
#  3   petal width in cm   150 non-null    float64
#  4   class               150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Statistics**

# %%
df.describe()
# Out:
#        sepal length in cm  ...  petal width in cm
# count          150.000000  ...         150.000000
# mean             5.843333  ...           1.198667
# std              0.828066  ...           0.763161
# min              4.300000  ...           0.100000
# 25%              5.100000  ...           0.300000
# 50%              5.800000  ...           1.300000
# 75%              6.400000  ...           1.800000
# max              7.900000  ...           2.500000
#
# [8 rows x 4 columns]

# %% [markdown]
# ### Pandas is a very important tool.  We will cover more after Winter Break!

# %% [markdown]
# ## Features, Samples, Targets

# %% [markdown]
# More terminologies: Features (Attributes), Samples (Instances, Observations), Class labels(Targets).
# ![alt text](https://www.apsl.net/media/apslweb/images/iris.original.png)

# %% [markdown]
# #<font color=' blue '>Exploratory Data Analysis (EDA)</font>

# %% [markdown]
# ## Seaborn Library

# %% [markdown]
# Seaborn is a very nice Python graph library, built on top of Matplotlib.  It wraps some difficult Matplotlib plots into easier to use plots.  It also comes with very pleasing color schemes.

# %%
import numpy as np

import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ![alt text](http://suruchifialoke.com/img/ML/iris.png)

# %% [markdown]
# Seanborn's pairplot shows histogram of each feature, and relationship between every two features in one plot.

# %%
g = sns.pairplot(df, hue='class', markers='+')

# %% [markdown]
# With the plots above, it is **clear that the relationship between pairs of features of a iris-setosa (in <font color='pink'>pink</font>) is distinctly different from those of the other two species**.

# %% [markdown]
# #### Seanborn is very good at generating Statistical charts.  We will cover more after the Winter Break.

# %% [markdown]
# ##Pandas could plot too!

# %%
from pandas.plotting import parallel_coordinates

# %%
parallel_coordinates(df, "class", color=('palevioletred','darkgoldenrod', 'green'))

# %% [markdown]
# It is clear that Iris-setosa is different in petal length and petal width above.

# %% [markdown]
# ## How would you predict Iris flower type of new data?

# %% [markdown]
# Now assuming you are given a Iris flow (i.e., with all four measurements), how would you naturally predict which Iris species will it be?
# <br><br>
# One way is to plot the data in the same chart.  If the new data point is closer than one particular species, we will predict this flower is of the same type.
#
# ![alt text](http://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1531424125/Knn_k1_z96jba.png)

# %% [markdown]
# # <font color='blue '>KNN Machine Learning Model</font>

# %% [markdown]
# Welcome to our first machine learning model!  This is one of the simplest ML models and the most intuitive too.

# %% [markdown]
# ## <font color=' #7cb342 '>KNN (K-Nearest Neighbors) Model</font>

# %% [markdown]
# KNN algorithms <u>classify new data points based on a similarity measures (e.g. distance function)</u>.  **Classification is done by a majority vote to its neighbors**:  the label is assigned to t**he class which has the most nearest neighbors**.

# %% [markdown]
# ![alt text](http://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1531424125/KNN_final1_ibdm8a.png)

# %% [markdown]
# ## KNN using Scikit-learn Machine Learning Library

# %% [markdown]
# Very popular machine learning library in Python.  Provide many machine learning models in easy-to-use ways.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import  accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### Split data into features and labels

# %%
features = df[['sepal length in cm', 
               'sepal width in cm', 
               'petal length in cm', 
               'petal width in cm']]
labels = df['class']

# %%
type(features)

# %%
type(labels)

# %%
labels.head()

# %% [markdown]
# #### Convert class labels into numbers

# %% [markdown]
# Class labels are strings.  We need to convert them into numbers that could be understood by computers.

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(labels)

# %% [markdown]
# As you can see Iris-setosa Iris-versicolor Iris-virginica are converted to 0, 1, 2 respectively.

# %%
y

# %% [markdown]
# #### Generate training set and test set

# %% [markdown]
# It is common practice when performing a (supervised) machine learning training to hold out part of the available data as a test set.  sk-learn will help us quickly sample a training set while holding out certain percentage of data for testing (evaluating) our model.  The command below will have a 7-3 split of training data vs. testing data.

# %%
# x_train, y_train will be used for training the model
# while x_test, y_test will be used for testing/evaluating the trained model
# random_state is the seed used by random number generator
# stratify=y ensures data is split in the stratified fashion
x_train, x_test, y_train, y_test = train_test_split(features, y, test_size = 0.3, 
                                                    random_state = 101, stratify=y)

# %% [markdown]
# The data count should show stratified effect.

# %%
print('Labels counts in y:', np.bincount(y))
print('Labels counts in y_train:', np.bincount(y_train))
print('Labels counts in y_test:', np.bincount(y_test))

# %% [markdown]
# #### Feature Scaling

# %% [markdown]
# Feature scaling is a method used to standardize the range of independent variables or features of data. In data processing, it is also known as data normalization and is generally performed during the data preprocessing step.

# %%
x_train.head()

# %%
sc = StandardScaler()

sc.fit(features)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

type(x_train_std)

# %%
x_train_std[:5]

# %% [markdown]
# #### Create KNN model

# %% [markdown]
# For parameter p below.  When p = 1, this is equivalent to using manhattan_distance, and euclidean_distance for p = 2 (default).
# ![alt text](https://www.bogotobogo.com/python/scikit-learn/images/k-NN/Euclidean-vs-Manhattan.png)

# %%
# K=3 below
knn_model = KNeighborsClassifier(n_neighbors=7, p=2)

# %% [markdown]
# #### Run KNN Machine Learning Process (Train model, Fit data)

# %%
knn_model.fit(x_train_std, y_train);

# %% [markdown]
# #### Run Prediction on test set

# %%
knn_predict = knn_model.predict(x_test_std)

# %% [markdown]
# #### Is the prediction accurate?

# %%
print('knn - test accuracy ', accuracy_score(knn_predict, y_test))

# %% [markdown]
# Is the prediction on train set 100% accurate?

# %%
y_train_predict = knn_model.predict(x_train_std)
print('knn - train accuracy ', accuracy_score(y_train_predict, y_train))

# %% [markdown]
# ####Identify the test samples predicted wrong

# %% [markdown]
# Get the index of the test samples predicted wrong.

# %%
test_predict_wrong = np.nonzero(knn_predict-y_test)
test_predict_wrong

# %%
knn_predict[test_predict_wrong]

# %%
y_test[test_predict_wrong]

# %% [markdown]
# Retrieve the normalized test data:

# %%
x_train_std[test_predict_wrong]

# %% [markdown]
# Retrieve the original test data:

# %%
x_train.iloc[test_predict_wrong]

# %% [markdown]
# ####Wow, so simple!!

# %% [markdown]
# #### How about non-stratified, non-normalized split?

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(features, y, test_size = 0.3, 
                                                    random_state = 101)

print('Labels counts in y:', np.bincount(y))
print('Labels counts in y_train1:', np.bincount(y_train1))
print('Labels counts in y_test1:', np.bincount(y_test1))

knn_model.fit(x_train1,y_train1)
knn_predict1 = knn_model.predict(x_test1)

print('knn - test accuracy ',accuracy_score(knn_predict1,y_test1))
y_train_predict1 = knn_model.predict(x_train1)
print('knn - train accuracy ', accuracy_score(y_train_predict1, y_train1))

# %% [markdown]
# #### 100% Accuracy!!

# %% [markdown]
# So is it by chance?  Is it because of non-stratification?  Or non-normalization?
#
# How about different random seeds, different split ratio, and different...?
#
# Model is just a means to approximate complex data.  We might never get the full data set, hence predicting for new data is always both **science** and **art**!  The reasonable goal is to achieve practical useful predictions, instead of 100% accuracy.

# %% [markdown]
# ## Visualize Decision/Plot Decision Regions

# %% [markdown]
# It is hard to visualize Machine Learning, which is often called as **Black Box**.  We will try to visualize the result below.

# %% [markdown]
# ### Helper functions.  Just run and skip.

# %%
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # highlight test samples
    if test_idx:
        # plot all samples
        X_test, y_test = X[test_idx, :], y[test_idx]
        c_test = [colors[i] for i in y_test]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c=c_test,
                    edgecolor='black',
                    alpha=0.8,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

# %% [markdown]
# ### Pick 2 features to visualize Decision Boundary

# %% [markdown]
# We will pick features: Petal Length and Petal Width.

# %%
X_train_std = x_train_std[:, 2:]
X_test_std  = x_test_std[:, 2:]

# Fit KNN model again
knn_model.fit(X_train_std, y_train);

# %% [markdown]
# Now visualized the Decision Boundary.

# %%
X_combined = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

plot_decision_regions(X_combined, y_combined, 
                      classifier=knn_model, test_idx=range(105, 150))

plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')

# %% [markdown]
# ## KNN model: Pros and Cons

# %% [markdown]
# ###Pros

# %% [markdown]
# 1.   It is extremely easy to implement
# 2.   It is, so called, lazy learning algorithm and therefore requires no training prior to making real time predictions. This makes the KNN algorithm much faster than other algorithms that require training.
# 3.   Since the algorithm requires no training before making predictions, new data can be added seamlessly.
# 4. It's easy to understand.

# %% [markdown]
# ### Cons

# %% [markdown]
# 1.   The KNN algorithm doesn't work well with high dimensional data because with large number of dimensions, it becomes difficult for the algorithm to calculate distance in each dimension.
# 2.   The KNN algorithm has a high prediction cost for large datasets. This is because in large datasets the cost of calculating distance between new point and each existing point becomes higher.
# 3. Finally, the KNN algorithm doesn't work well with categorical features since it is difficult to find the distance between dimensions with categorical features.

# %% [markdown]
# # <font color='gold'>Create Automatic Stock Trading Strategy, using KNN ML Model</font>

# %% [markdown]
# We could create a Auto Stock Trading Strategy using KNN model.  Such a trading strategy is also known as, <b>Machine Trading Strategy</b>, <b>Algorithmic Trading Strategy</b> (or <b>Algo Trading Strategy</b>), <b>Black Box Trading Strategy</b> or <b>Quantitative Trading Strategy</b>.
# <br><br>
# As we all know, it's hard to create a consistent money maker.  Our strategy is not an exception either.  It's a basic, single strategy.  To be used in real life, it will need a lot of tuning, backtesting and most likely be combined with other trading strategies and risk managements.
# <br><br>
# But for now, let's go ahead to create our first Algo Trading Strategy!

# %% [markdown]
# ## Business Requirements and Trading Strategy Specification

# %% [markdown]
# ### Which Stock to Trade?

# %% [markdown]
# We will trade stock [SPY](https://finance.yahoo.com/quote/SPY?p=SPY&.tsrc=fin-srch).  This stock tracks [S&P 500 index](https://en.wikipedia.org/wiki/S%26P_500_Index).
# <br><br>
# Our strategy should be able to work on any stocks.  Noted that different stocks might need different model parameters

# %% [markdown]
# ### Trading Strategy Specification

# %% [markdown]
# Our strategy will use prior 3 month stock data to build KNN model and trade stock daily for the next month.
# <br><br>
# At the end of the next month, we will then rebuild our KNN model using the latest 3 month stock data and use the updated model to trade the next next month.
# <br><br>
# We plan to continue trading like this forever.

# %% [markdown]
# ### Initial Trading Strategy Development and Ongoing Maintenance

# %% [markdown]
# If the model is not working very well for a couple of month, we might tune our strategy by changing the parameter of our Machine Learning model.  Specifically, we might change the number of neighbors parameter of KNN model and back-test to make sure it works.
# <br><br>
# We might also change the time period for Machine Learning model input (currently it's 3 month) and/or the Trading time period (currently 1 month).

# %% [markdown]
# ## Data Acquisition

# %% [markdown]
# We will use pandas_datareader module to load daily stock price from financial web site: http://finance.yahoo.com

# %%
from pandas_datareader import data as pdr

# %% [markdown]
# Load daily stock price from 2018-09-01 to 2019-01-01.  The data from the first 3 month (2018-09-01 to 2018-12-01) will be used for model input.  The data for the last month (2018-12-01 to 2019-01-01) will be used for simulated trading.

# %%
df = pdr.get_data_yahoo('SPY', '2018-09-01', '2019-01-01')

# %% [markdown]
# ## Data Cleaning/Preprocessing

# %%
df = df.dropna()

# %%
df = df[['Open', 'High', 'Low', 'Close']]

# %%
df.head()

# %% [markdown]
# ## Feature Engineering

# %%
# With feature scaling
#df['Open-Close'] = 100*(df.Open - df.Close)/df.Close.shift(-1)
#df['High-Low'] = 100*(df.High - df.Low)/df.Close.shift(-1)

# Without feature scaling
df['Open-Close'] = df.Open - df.Close
df['High-Low'] = df.High - df.Low
df = df.dropna()
X=df[['Open-Close', 'High-Low']]
X.head()

# %% [markdown]
# ## Trading Signal

# %% [markdown]
# The target variable is whether tomorrow's closing price is higher than today's closing price.
# <br><br>
# This target variable is our trading signal:
# > If signal tells us that tomorrow's closing price will be **higher**, then the strategy will **buy** stock at today's closing price and **sell** stock at tomorrow's closing price.
# >
# >If signal tells us that tomorrow's closing price will be **lower**, then the strategy will **sell** stock at today's closing price and **buy back** the stock to tomorrow's closing price.

# %%
Y = np.where(df['Close'].shift(-1)>df['Close'], 1, -1)

# %% [markdown]
# ## Prepare Model Input and Simulated Trading Data

# %%
split_percentage = 0.75
split = int(split_percentage * len(df))

#With 4 month data, the first 75% data (3 month) will be for model input
X_train = X[:split]
Y_train = Y[:split]

#The last 25% data (1 month) will be for simulated trading/testing
X_test = X[split:]
Y_test = Y[split:]

# %% [markdown]
# ## Train KNN Model

# %%
knn = KNeighborsClassifier(n_neighbors=25)

knn.fit(X_train, Y_train)

accuracy_train = accuracy_score(Y_train, knn.predict(X_train))

print('Train_data Accuracy: %.2f' %accuracy_train)

# %% [markdown]
# ## Simulate Trading

# %%
accuracy_test = accuracy_score(Y_test, knn.predict(X_test))

print('Test_data Accuracy: %.2f' %accuracy_test)

# %% [markdown]
# Calculate cumulative return

# %%
df['Predicted_Signal'] = knn.predict(X)

df['SPY_Returns'] = np.log(df['Close']/df['Close'].shift(1))
Cumulative_SPY_Returns = df[split:]['SPY_Returns'].cumsum()*100

df['KNN_Strategy_Returns'] = df['SPY_Returns'] * df['Predicted_Signal'].shift(1)
Cumulative_KNN_Strategy_Returns = df[split:]['KNN_Strategy_Returns'].cumsum()*100

print("Simulate trading from "+str(X[split:].index[0])[:10]+" to "+str(X[split:].index[-1])[:10]+" :")
print('KNN Strategy Extra Return Percentage = %.2f' %(Cumulative_KNN_Strategy_Returns[-1]-Cumulative_SPY_Returns[-1]))

print("\n")
print(df[split:]['Predicted_Signal'])

plt.figure(figsize=(10,5))
plt.plot(Cumulative_SPY_Returns, color='r', label='SPY Returns')
plt.plot(Cumulative_KNN_Strategy_Returns, color='g', label='KNN Strategy Returns', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# **<font color='red'>KNN model beats the market index/benchmark by 21.45% last month!!</font>**The result is so good!  Unbelieveable!!
# <br><br>
# With 67% accuracy, well, it's really too good to be true for the long run.
# <br><br>
# The performance for previous months is less impressive, even though still acceptable.  Try them yourself.

# %% [markdown]
# ##  This strategy could work for longer time periods too

# %% [markdown]
# It used to produce good performance using long term data too.
# <br>
# The example below is using trading data from 2012/01/01 to 2015/07/01 to trade 2015/07/02 to 2016/12/29.  KNN strategy beat stock market benchmark SPY by more than 7%.

# %%
bestk = 0
bestPercent = ""


for i in range(1, 255):

  df = pdr.get_data_yahoo('SPY', '1990-11-01', '2019-01-13')

  df = df.dropna()
  
  df = df[['Open', 'High', 'Low', 'Close']]

  df['Open-Close'] = df.Open - df.Close
  df['High-Low'] = df.High - df.Low
  df = df.dropna()
  X=df[['Open-Close', 'High-Low']]

  Y = np.where(df['Close'].shift(-1)>df['Close'], 1, -1)

  split_percentage = 0.7
  split = int(split_percentage * len(df))

  #With 4 month data, the first 70% data will be for model input
  X_train = X[:split]
  Y_train = Y[:split]

  #The last 30% data will be for simulated trading/testing
  X_test = X[split:]
  Y_test = Y[split:]

  knn = KNeighborsClassifier(n_neighbors=i)

  knn.fit(X_train, Y_train)

  accuracy_train = accuracy_score(Y_train, knn.predict(X_train))

  accuracy_test = accuracy_score(Y_test, knn.predict(X_test))

  df['Predicted_Signal'] = knn.predict(X)

  df['SPY_Returns'] = np.log(df['Close']/df['Close'].shift(1))
  Cumulative_SPY_Returns = df[split:]['SPY_Returns'].cumsum()*100

  df['KNN_Strategy_Returns'] = df['SPY_Returns'] * df['Predicted_Signal'].shift(1)
  Cumulative_KNN_Strategy_Returns = df[split:]['KNN_Strategy_Returns'].cumsum()*100

  current = Cumulative_KNN_Strategy_Returns[-1]-Cumulative_SPY_Returns[-1]
  print("Percent: " + current + " K: "+ k)
   

  if(current>bestPercent):
     bestk = i
     bestPercent = current+""
      
  

  #print(df[split:]['Predicted_Signal'])
print('best: ')
print(bestk)
print(bestPercent)

# %% [markdown]
# ## Try yourself

# %% [markdown]
# ### But it did not work well last 2 years

# %% [markdown]
# Try with different time periods:

# %%
# Good long run
#df = pdr.get_data_yahoo('SPY', '2012-01-01', '2017-01-01')

# Excellent near term
#df = pdr.get_data_yahoo('SPY', '2018-09-01', '2019-01-01')

# Worse than market performance
#df = pdr.get_data_yahoo('SPY', '2018-01-01', '2018-06-01')

# No extra return at all for this period
df = pdr.get_data_yahoo('SPY', '2017-08-01', '2018-01-01')


df = df.dropna()

df = df[['Open', 'High', 'Low', 'Close']]

# With feature scaling
df['Open-Close'] = 100*(df.Open - df.Close)/df.Close.shift(-1)
df['High-Low'] = 100*(df.High - df.Low)/df.Close.shift(-1)
df = df.dropna()
X=df[['Open-Close', 'High-Low']]

Y = np.where(df['Close'].shift(-1)>df['Close'], 1, -1)

split_percentage = 0.75
split = int(split_percentage * len(df))

#With 4 month data, the first 75% data will be for model input
X_train = X[:split]
Y_train = Y[:split]

#The last 25% data will be for simulated trading/testing
X_test = X[split:]
Y_test = Y[split:]

knn = KNeighborsClassifier(n_neighbors=25)

knn.fit(X_train, Y_train)

accuracy_train = accuracy_score(Y_train, knn.predict(X_train))

print('Train_data Accuracy: %.2f' %accuracy_train)

accuracy_test = accuracy_score(Y_test, knn.predict(X_test))

print('Test_data Accuracy: %.2f' %accuracy_test)

df['Predicted_Signal'] = knn.predict(X)

df['SPY_Returns'] = np.log(df['Close']/df['Close'].shift(1))
Cumulative_SPY_Returns = df[split:]['SPY_Returns'].cumsum()*100

df['KNN_Strategy_Returns'] = df['SPY_Returns'] * df['Predicted_Signal'].shift(1)
Cumulative_KNN_Strategy_Returns = df[split:]['KNN_Strategy_Returns'].cumsum()*100

print("\n")
print("Simulate trading from "+str(X[split:].index[0])[:10]+" to "+str(X[split:].index[-1])[:10]+" :")
print('KNN Strategy Extra Return Percentage = %.2f' %(Cumulative_KNN_Strategy_Returns[-1]-Cumulative_SPY_Returns[-1]))

#print(df[split:]['Predicted_Signal'])
print("\n")
print(X[split:].head(3))
print("...")
print(X[split:].tail(3))

plt.figure(figsize=(10,5))
plt.plot(Cumulative_SPY_Returns, color='r', label='SPY Returns')
plt.plot(Cumulative_KNN_Strategy_Returns, color='g', label='KNN Strategy Returns', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# **Summary of recent performance (with feature scaling):**
#
# KNN Strategy Extra Return Percentage = 0.0
# <br>
# df = pdr.get_data_yahoo('SPY', '2017-08-01', '2018-01-01')
#
# KNN Strategy Extra Return Percentage = 0.0
# <br>
# df = pdr.get_data_yahoo('SPY', '2017-09-01', '2018-02-01')
#
# KNN Strategy Extra Return Percentage = 0.0
# <br>
# df = pdr.get_data_yahoo('SPY', '2017-10-01', '2018-03-01')
#
# KNN Strategy Extra Return Percentage = 0.62
# <br>
# df = pdr.get_data_yahoo('SPY', '2017-11-01', '2018-04-01')
#
# KNN Strategy Extra Return Percentage = -8.57
# <br>
# df = pdr.get_data_yahoo('SPY', '2017-12-01', '2018-05-01')
#
# KNN Strategy Extra Return Percentage = -3.0
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-01-01', '2018-06-01')
#
# KNN Strategy Extra Return Percentage = -0.05
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-02-01', '2018-07-01')
#
# KNN Strategy Extra Return Percentage = -5.36
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-04-01', '2018-08-01')
#
# KNN Strategy Extra Return Percentage = -2.03
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-05-01', '2018-09-01')
#
# KNN Strategy Extra Return Percentage = -2.06
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-05-01', '2018-10-01')
#
# KNN Strategy Extra Return Percentage = 6.44
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-07-01', '2018-11-01')
#
# KNN Strategy Extra Return Percentage = -3.64
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-08-01', '2018-12-01')
#
# KNN Strategy Extra Return Percentage = 22.93 !!
# <br>
# df = pdr.get_data_yahoo('SPY', '2018-09-01', '2019-01-01')

# %% [markdown]
# ### Try different number of neighbors, different input time periods, and different trading periods

# %% [markdown]
# Could the number of neighbors be 20? 15? 50? 5?  Are the results different?

# %% [markdown]
# Could you write a function to make the trying process easier?

# %% [markdown]
# ## <font color='gold'>What could we take away from backtesting?</font>

# %% [markdown]
# 1.   Quantitative Strategy could work in stock market
# 2.   Certain Strategy works well in certain periods, but not too well in other periods (for those periods, maybe other Strategies could do well)
# 3.   Even a simple Strategy, like the KNN strategy above, could work.  But stock market is different than Natural Science: it could change dramatically far more frequent.  Hence as a Algorithmic Trader, you need to keep monitoring your strategy and fine tune the parameters of your strategy.  Or, you might need to combine the strategy with other strategies. Or, be ready to abandon the strategy completely and switch to other new strategies.
